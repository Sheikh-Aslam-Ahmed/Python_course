#        -5.46316984e-01, -2.64381584e+00,  5.78560322e-01,  1.26149006e+00,
#         4.79103728e-01,  8.08320724e-01,  1.24812215e+00,  4.66235066e-01,
#        -5.65278834e-01,  8.68280520e-01,  3.14581829e-01,  8.45007919e-01,
#        -1.83188563e-01, -3.23666934e-01,  1.92138159e+00,  5.83616861e-01,
#         2.02607446e-01, -8.05966603e-01, -3.45737104e-01, -1.18977091e+00,
#         1.81361600e+00,  2.45264323e+00,  2.24712555e+00, -1.06370840e+00,
#         1.14649605e+00,  1.27384451e+00,  5.33532242e-02, -4.55658078e-01,
#        -8.24292999e-01,  1.50587977e-01,  3.05130199e-01, -1.92522388e-01,
#         1.33093929e+00, -3.01388293e-01, -1.13440843e+00,  4.22911073e-01,
#        -4.87934021e-01, -2.68591216e-01, -2.48877188e-01,  6.67501022e-01,
#        -1.84845941e+00,  8.92784446e-01,  5.35225788e-01,  1.14464485e+00,
#        -8.47976409e-02, -1.57678616e+00, -4.36138734e-01,  1.36734917e+00,
#         1.70261263e+00,  1.23780504e+00, -2.18823480e-01, -1.11383519e+00,
#         6.81269887e-02, -1.58183319e+00,  2.23020368e-01, -6.94407669e-01,
#        -1.56342041e+00,  4.77427464e-01, -5.36513648e-01, -8.95561281e-01,
#         8.65268434e-01, -1.46019182e+00, -8.22018046e-01,  1.23460784e+00,
#        -5.08375094e-01,  4.60850363e-01, -2.42426941e-01,  1.28757269e+00,
#         2.72290258e-01,  3.51806773e-01,  2.96497517e-01,  2.25963373e-01,
#        -6.51634835e-01,  1.28603127e+00,  1.22182258e+00, -1.15926059e+00,
#        -7.72184235e-01, -6.92553476e-01, -1.00647557e+00,  1.03896943e+00,
#         1.96400895e+00, -6.85869711e-02, -1.68328377e-01,  2.43240829e-01,
#         9.43793482e-01,  4.73118527e-01,  7.84014904e-01, -1.51229184e+00,
#         1.21574663e+00,  1.16818794e+00,  1.30103844e+00,  2.21842496e-01,
#        -9.40060241e-01,  3.85918371e-01,  1.15272850e+00,  1.88002679e+00,
#        -2.18998211e+00, -3.29040779e-01, -3.64583460e-01, -4.31377165e-01,
#         7.29665397e-01,  9.86797703e-01,  4.19707395e-01, -9.90678643e-01,
#         8.75731893e-01, -7.05850181e-01, -8.00847394e-01,  1.14933105e-01,
#         1.07597530e+00, -1.28859608e+00, -2.07745943e-01,  1.05680636e+00,
#        -5.95025119e-01, -6.91565331e-01,  1.29926885e-02,  1.21088819e+00,
#        -3.56188717e-02,  1.48838492e+00, -3.75437407e-01, -9.83503149e-02,
#        -3.73144573e-01, -6.88740472e-01, -1.38027343e+00, -6.29184893e-01])

# %%
df = pd.DataFrame(randn(1000),index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])

# %%
df
# Out:
#                value
# 2019-06-07 -0.391017
# 2019-06-08 -0.462923
# 2019-06-09  0.480356
# 2019-06-10 -1.851546
# 2019-06-11 -1.198083
# ...              ...
# 2022-02-26 -0.219273
# 2022-02-27  0.124538
# 2022-02-28  0.746332
# 2022-03-01 -0.627409
# 2022-03-02  0.932466
#
# [1000 rows x 1 columns]

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07 -0.269066
# 2019-06-08  0.953197
# 2019-06-09 -0.040682
# 2019-06-10  1.475170
# 2019-06-11 -1.162130

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07  0.971179
# 2019-06-08 -0.415507
# 2019-06-09 -1.039253
# 2019-06-10 -1.092607
# 2019-06-11 -2.446935

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07    0.520655
# 2019-06-08    0.022088
# 2019-06-09    1.644353
# 2019-06-10    0.292254
# 2019-06-11    0.281113
# Freq: D, dtype: float64

# %%
ts.head()
# Out:
# 2019-06-07    0.520655
# 2019-06-08    0.022088
# 2019-06-09    1.644353
# 2019-06-10    0.292254
# 2019-06-11    0.281113
# Freq: D, dtype: float64

# %%
ts.plot(figsize=(5,5))

# %%
plt.plot(ts)

# %%
ts
# Out:
# 2019-06-07     0.520655
# 2019-06-08     0.022088
# 2019-06-09     1.644353
# 2019-06-10     0.292254
# 2019-06-11     0.281113
#                 ...
# 2022-02-26   -13.176168
# 2022-02-27   -13.976132
# 2022-02-28   -13.524326
# 2022-03-01   -13.193447
# 2022-03-02   -14.565158
# Freq: D, Length: 1000, dtype: float64

# %%
df.head()
# Out:
#                value
# 2019-06-07 -0.269066
# 2019-06-08  0.953197
# 2019-06-09 -0.040682
# 2019-06-10  1.475170
# 2019-06-11 -1.162130

# %%
df.plot(kind ='line')

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -1.084443 -0.305217 -0.464633  1.017787
# 1 -0.333498 -0.042546 -0.814587  0.231063
# 2  0.559458  0.705838  0.283314 -0.127366
# 3  1.032446  1.336165 -0.168365 -0.020222
# 4  1.071943  0.776933 -1.181797  1.077948
# 5 -0.022133 -0.287401 -0.761377  0.513178
# 6  0.340251  0.949486 -0.198043  1.239277
# 7  0.013928  0.258250 -0.591135  0.908302
# 8  2.124873  1.352250  0.879412  0.639551
# 9 -0.861206 -0.702369  1.004040  2.861642

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['sepal_length'].plot.hist()

# %%
iris.plot(kind = 'hist', stacked = True, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = False, bins = 10)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'r', alpha = 0.7, figsize=(20,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000018B0AC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000018B7D088>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000018BB2348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000018BE49C8>]],
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df = iris

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')

# %%
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', color = 'r')

# %%
ax = df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 30)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 50, C = 'sepal_width')

# %%
df = iris.drop(['species'], axis = 1)
d = df.iloc[0]

d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (5,5))

# %%
df.head(3).T
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (15,15))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000000192D6248>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000019309708>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000192D6A48>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000000193DF4C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001941A388>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000193EC688>],
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
# KDE - kernal density estimation 
scatter_matrix(df, figsize= (8,8),  color = 'r',diagonal='kde')
plt.show()

# %%
ts.plot.kde()

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001CF05D48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001CF1F048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001CF00D48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001CF87748>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()
