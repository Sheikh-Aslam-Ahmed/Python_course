# %% [markdown]
# # Task 1

# %% [markdown]
# 1.1 Write a Python Program to implement your own myreduce() function which works exactly like Python's built-in function reduce()

# %%
def reduce(function, iterable, initializer=None):
    iterater = iter(iterable)
    if initializer is None:
        try:
            initializer = next(iterater)
        except Exception as ex:
            print(ex)
    acc_value = initializer
    for x in iterater:
        acc_value = function(acc_value, x)
    return acc_value

# %%
lis = [ 1 , 3, 5, 6, 2 ] 
print ("The sum of the list elements is : ",end="") 
print (reduce(lambda a,b : a+b,lis))
# Out:
# The sum of the list elements is : 17

# %% [markdown]
# Output:
# ![image.png](attachment:image.png)

# %% [markdown]
# 1.2 Write a Python program to implement your own myfilter() function which works exactly like Python's built-in function filter()

# %%
def filter(function, iterable):
    iterater = iter(iterable)
    return [x for x in iterater if function(x)]

# %%
# a list contains both even and odd numbers.  
seq = [0, 1, 2, 3, 5, 8, 13] 
  
# result contains odd numbers of the list 
result = filter(lambda x: x % 2 != 0, seq) 
print(list(result)) 
  
# result contains even numbers of the list 
result = filter(lambda x: x % 2 == 0, seq) 
print(list(result))
# Out:
# [1, 3, 5, 13]
# [0, 2, 8]

# %% [markdown]
# Output:
# ![image.png](attachment:image.png)

# %% [raw]
# 2. Implement List comprehensions to produce the following lists.
# Write List comprehensions to produce the following Lists
# ['A', 'C', 'A', 'D', 'G', 'I', ’L’, ‘ D’]
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xx', 'yy', 'zz', 'xxxx', 'yyyy', 'zzzz']
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]

# %% [markdown]
# Output:

# %% [markdown]
# 3. Implement a function longestWord() that takes a list of words and returns the longest one.

# %%
def largestWord(list=[], *args):
    largestWord=""
    largestWordLen=0
    for word in list:
        if largestWordLen<len(word):
            largestWordLen=len(word)
            largestWord=word
    return largestWord

colors=["red","green","yellow","blue"]

longestWord = largestWord(colors)
print("The longest word in the list is %s." %longestWord)
# Out:
# The longest word in the list is yellow.

# %% [markdown]
# Output:
# ![image.png](attachment:image.png)

# %% [markdown]
# # Task 2

# %% [markdown]
# 1.1 Write a Python Program(with class concepts) to find the area of the triangle using the below
# formula.
# area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
# Function to take the length of the sides of triangle from user should be defined in the parent
# class and function to calculate the area should be defined in subclass.

# %%
class polygon:
    def __init__(self, no_of_sides):
        self.n = no_of_sides
        self.sides = [0 for i in range(no_of_sides)]
        
    def inputSides(self):
        self.sides = [float(input("Enter side "+str(i+1)+" : ")) for i in range(self.n)]
        
class trangle(polygon):
    def __init__(self):
        polygon.__init__(self,3)

    def findArea(self):
        a, b, c = self.sides
        # calculate the semi-perimeter
        s = (a + b + c) / 2
        area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
        print('The area of the triangle is %0.2f' %area)
    
t = trangle()
t.inputSides()
t.findArea()
# Out:
# Enter side 1 : 4
# Enter side 2 : 4
# Enter side 3 : 4
# The area of the triangle is 6.93

# %% [markdown]
# Output:
# ![image.png](attachment:image.png)

# %% [raw]
# 1.2 Write a function filter_long_words() that takes a list of words and an integer n and returns the list
# of words that are longer than n.

# %%
# list of words
words = ['alpha', 'gama', 'beta', 'theta', 'sin', 'cos', 'tan']

# function that filters words based on size
def filter_long_words(wordlist,size):
    filteredWords =[]
    for word in wordlist:
        if  len(word) > size:
            filteredWords.append(word)
    return filteredWords
            
filteredWords = filter_long_words(words, 4)

print('The filtered words are:')
for word in filteredWords:
    print(word)
# Out:
# The filtered words are:
# alpha
# theta

# %% [markdown]
# Output:
# ![image.png](attachment:image.png)

# %% [raw]
# 2.1 Write a Python program using function concept that maps list of words into a list of integers
# representing the lengths of the corresponding words.
# Hint: If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4]
# Here 2,3 and 4 are the lengths of the words in the list.

# %%
# list of words
words = ['alpha', 'gama', 'beta', 'theta', 'sin', 'cos', 'tan']

def word_to_length(wordlist):
    lengthlist = []
    for word in wordlist:
            lengthlist.append(len(word))
    return lengthlist
            
lengthlist = word_to_length(words)

print('The length list is :')
print(*lengthlist)
# Out:
# The length list is :
# 5 4 4 5 3 3 3

# %% [markdown]
# Output:
# ![image.png](attachment:image.png)

# %% [raw]
# 2.2 Write a Python function which takes a character (i.e. a string of length 1) and returns True if it is
# a vowel, False otherwise.

# %%
# list of alphabets
alphabets = ['a', 'b', 'd', 'e', 'i', 'j', 'o']

# function that filters vowels
def filterVowels(alphabet):
    vowels = ['a', 'e', 'i', 'o', 'u']

    if(alphabet in vowels):
        return True
    else:
        return False

filteredVowels = filter(filterVowels, alphabets)

print('The filtered vowels are:')
print(*filteredVowels, sep = ", ")
# Out:
# The filtered vowels are:
# a, e, i, o

# %% [markdown]
# Output:
# ![image.png](attachment:image.png)
