# %% [markdown]
# # Pandas in Python

# %%
#import the pandas library and aliasing as pd
import pandas as pd

# %%
df = pd.read_csv("test.csv")
df
# Out:
#    col1 col2  col3  col4  col5
# 0     1  sfs   343  dfde  5343
# 1     2  dfd   454  gdds  5666
# 2     3  ddf   456  tgsg  5678

# %%
df = pd.rea_csv("test.csv",header=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-fbb360451445> in <module>
# ----> 1 df = pd.rea_csv("test.csv",header=None)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'rea_csv'

# %%
df5 = pd.read_csv("ex5.csv")
df5
# Out:
#    id name    rol surname  score
# 0   1  sfs  343.0    dfde   5343
# 1   2  dfd    NaN    gdds   5666
# 2   3  ddf  456.0     NaN   5678

# %%
df5 = pd.read_csv("ex5.csv", na_value=["one",8])
df5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-258e9345c6b8> in <module>
# ----> 1 df5 = pd.read_csv("ex5.csv", na_value=["one",8])
#       2 df5
#
# TypeError: parser_f() got an unexpected keyword argument 'na_value'

# %% [markdown]
# # read HTML

# %%
nba_total_data = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
nba_total_data[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
titanic_data=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv',sep='\t')

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# store as CSV file 
titanic_data.to_csv('titanic_data.csv')

# %%
# store as table (tab seperated format)
titanic_data.to_csv('titanic_data_table.tsv',sep='\t')

# %%
# store as CSV file 
titanic_data.to_csv('titanic_data_2.csv',index=False, header=False)

# %%
# rename column name
df5 = pd.read_csv("ex5.csv",names=[1,2,3,4,5])
df5
# Out:
#     1     2    3        4      5
# 0  id  name  rol  surname  score
# 1   1   sfs  343     dfde   5343
# 2   2   dfd  NaN     gdds   5666
# 3   3   ddf  456      NaN   5678

# %% [markdown]
# # Reading and wrinting in binary file

# %%
# writing to binary file(pickle file) - serialization
df5.to_pickle("ex5pickle")

# %%
# reading from binary file(pickle file) - deserialization
df6 = pd.read_pickle("ex5pickle")
df6
# Out:
#     1     2    3        4      5
# 0  id  name  rol  surname  score
# 1   1   sfs  343     dfde   5343
# 2   2   dfd  NaN     gdds   5666
# 3   3   ddf  456      NaN   5678
